# %%
from nba_api.stats.static import players
import pandas as pd

df_players = pd.DataFrame(players.get_players())
df_players.to_csv("../data/raw/players.csv", index=False)
df_players.head()
# Out:
#       id            full_name first_name     last_name  is_active
# 0  76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1  76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2  76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3     51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4   1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False

# %%
from nba_api.stats.static import teams

df_teams = pd.DataFrame(teams.get_teams())
df_teams.to_csv("../data/raw/teams.csv", index=False)
df_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
from nba_api.stats.endpoints import leaguedashplayerstats

stats = leaguedashplayerstats.LeagueDashPlayerStats(
    season="2025-26",
    season_type_all_star="Regular Season",
    per_mode_detailed="PerGame"
)

df_stats = stats.get_data_frames()[0]
df_stats.to_csv("../data/raw/season_stats_2025-26.csv")
df_stats.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     719 try:
# --> 720     return self._sock.recv_into(b)
#     721 except timeout:
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#
# File ~\AppData\Local\Python\pythoncore-3.12-64\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1102 if buffer is not None:
# -> 1103     return self._sslobj.read(len, buffer)
#    1104 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\requests\adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\urllib3\connectionpool.py:842, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840     new_e = ProtocolError("Connection aborted.", new_e)
# --> 842 retries = retries.increment(
#     843     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     844 )
#     845 retries.sleep()
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\urllib3\util\retry.py:498, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     497 if read is False or method is None or not self._is_method_retryable(method):
# --> 498     raise reraise(type(error), error, _stacktrace)
#     499 elif read is not None:
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\urllib3\connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\urllib3\connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[14], line 3
#       1 from nba_api.stats.endpoints import leaguedashplayerstats
#       2
# ----> 3 stats = leaguedashplayerstats.LeagueDashPlayerStats(
#       4     season="2025-26",
#       5     season_type_all_star="Regular Season",
#       6     per_mode_detailed="PerGame"
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\nba_api\stats\endpoints\leaguedashplayerstats.py:194, in LeagueDashPlayerStats.__init__(self, last_n_games, measure_type_detailed_defense, month, opponent_team_id, pace_adjust, per_mode_detailed, period, plus_minus, rank, season, season_type_all_star, college_nullable, conference_nullable, country_nullable, date_from_nullable, date_to_nullable, division_simple_nullable, draft_pick_nullable, draft_year_nullable, game_scope_simple_nullable, game_segment_nullable, height_nullable, league_id_nullable, location_nullable, outcome_nullable, po_round_nullable, player_experience_nullable, player_position_abbreviation_nullable, season_segment_nullable, shot_clock_range_nullable, starter_bench_nullable, team_id_nullable, two_way_nullable, vs_conference_nullable, vs_division_nullable, weight_nullable, proxy, headers, timeout, get_request)
#     155 self.parameters = {
#     156     "LastNGames": last_n_games,
#     157     "MeasureType": measure_type_detailed_defense,
#    (...)    191     "Weight": weight_nullable,
#     192 }
#     193 if get_request:
# --> 194     self.get_request()
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\nba_api\stats\endpoints\leaguedashplayerstats.py:197, in LeagueDashPlayerStats.get_request(self)
#     196 def get_request(self):
# --> 197     self.nba_response = NBAStatsHTTP().send_api_request(
#     198         endpoint=self.endpoint,
#     199         parameters=self.parameters,
#     200         proxy=self.proxy,
#     201         headers=self.headers,
#     202         timeout=self.timeout,
#     203     )
#     204     self.load_response()
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\nba_api\library\http.py:160, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     157         print("loading from file...")
#     159 if not contents:
# --> 160     response = self.get_session().get(
#     161         url=base_url,
#     162         params=parameters,
#     163         headers=request_headers,
#     164         proxies=proxies,
#     165         timeout=timeout,
#     166     )
#     167     url = response.url
#     168     status_code = response.status_code
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\requests\sessions.py:671, in Session.get(self, url, params, **kwargs)
#     661 r"""Sends a GET request. Returns :class:`Response` object.
#     662
#     663 :param url: URL for the new :class:`Request` object.
#    (...)    667 :rtype: requests.Response
#     668 """
#     670 kwargs.setdefault("allow_redirects", True)
# --> 671 return self.request("GET", url, params=params, **kwargs)
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\requests\sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\requests\sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File c:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard\.venv\Lib\site-packages\requests\adapters.py:742, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     740     raise SSLError(e, request=request)
#     741 elif isinstance(e, ReadTimeoutError):
# --> 742     raise ReadTimeout(e, request=request)
#     743 elif isinstance(e, _InvalidHeader):
#     744     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)

# %%
from nba_api.stats.endpoints import drafthistory

# Pull full draft history
dh = drafthistory.DraftHistory(league_id='00')
df_draft = dh.get_data_frames()[0]

df_draft.to_csv("../data/raw/rookies.csv", index=False)
df_draft.head(10)
# Out:
#    PERSON_ID           PLAYER_NAME SEASON  ROUND_NUMBER  ROUND_PICK  \
# 0    1642843          Cooper Flagg   2025             1           1
# 1    1642844          Dylan Harper   2025             1           2
# 2    1642845          VJ Edgecombe   2025             1           3
# 3    1642851          Kon Knueppel   2025             1           4
# 4    1642846            Ace Bailey   2025             1           5
# 5    1642848           Tre Johnson   2025             1           6
# 6    1642847        Jeremiah Fears   2025             1           7
# 7    1642856            Egor Dëmin   2025             1           8
# 8    1642867  Collin Murray-Boyles   2025             1           9
# 9    1642863        Khaman Maluach   2025             1          10
#
#    OVERALL_PICK DRAFT_TYPE     TEAM_ID     TEAM_CITY  TEAM_NAME  \
# 0             1      Draft  1610612742        Dallas  Mavericks
# 1             2      Draft  1610612759   San Antonio      Spurs
# 2             3      Draft  1610612755  Philadelphia      76ers
# 3             4      Draft  1610612766     Charlotte    Hornets
# 4             5      Draft  1610612762          Utah       Jazz
# 5             6      Draft  1610612764    Washington    Wizards
# 6             7      Draft  1610612740   New Orleans   Pelicans
# 7             8      Draft  1610612751      Brooklyn       Nets
# 8             9      Draft  1610612761       Toronto    Raptors
# 9            10      Draft  1610612745       Houston    Rockets
#
#   TEAM_ABBREVIATION    ORGANIZATION   ORGANIZATION_TYPE  PLAYER_PROFILE_FLAG
# 0               DAL            Duke  College/University                    1
# 1               SAS         Rutgers  College/University                    1
# 2               PHI          Baylor  College/University                    1
# 3               CHA            Duke  College/University                    1
# 4               UTA         Rutgers  College/University                    1
# 5               WAS           Texas  College/University                    1
# 6               NOP        Oklahoma  College/University                    1
# 7               BKN   Brigham Young  College/University                    1
# 8               TOR  South Carolina  College/University                    1
# 9               HOU            Duke  College/University                    1
