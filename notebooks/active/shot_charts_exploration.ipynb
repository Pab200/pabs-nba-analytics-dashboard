# %%
import sys
PROJECT_ROOT = r"C:\Users\Pablo Miller\proyectos\pabs-nba-analytics-dashboard"
sys.path.insert(0, PROJECT_ROOT)

# %%
import pandas as pd
from nba_api.stats.endpoints import shotchartdetail

# %%
PLAYER_ID = 201939
SEASON = "2023-24"
SEASON_TYPE = "Regular Season"

# %%
sc = shotchartdetail.ShotChartDetail(
    team_id=0,
    player_id=PLAYER_ID,
    season_type_all_star=SEASON_TYPE,
    season_nullable=SEASON,
    context_measure_simple="FGA"
)

shot_df = sc.get_data_frames()[0]
shot_df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  ...  GAME_DATE  HTM  VTM
# 0  Shot Chart Detail  0022300005             40  ...   20231103  OKC  GSW
# 1  Shot Chart Detail  0022300005             53  ...   20231103  OKC  GSW
# 2  Shot Chart Detail  0022300005            249  ...   20231103  OKC  GSW
# 3  Shot Chart Detail  0022300005            281  ...   20231103  OKC  GSW
# 4  Shot Chart Detail  0022300005            292  ...   20231103  OKC  GSW
#
# [5 rows x 24 columns]
